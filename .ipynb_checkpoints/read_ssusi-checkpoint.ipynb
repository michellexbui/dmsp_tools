# %%
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import pandas as pd
from netCDF4 import Dataset

# %%
def plot_SSUSI(image,mlat,mlt,maxi,mini,time_stamp):

    fig=plt.figure()
    plt.subplots_adjust(left = 0.15,
            right=0.85,
            wspace = 0.03,hspace = 0.03)
    ax = fig.add_subplot(1,1,1,polar=True)

    #plot polar map
    theta = mlt*15.0*np.pi/180.0-np.pi/2
    rad = 90.0-mlat

    hs=ax.scatter(theta,rad,c=image,
            s=0.5,vmin=mini,vmax=maxi,
            cmap='plasma',alpha=0.6)
    levels = [0.0,10,20,30,40]
    ax.set_rticks(levels)
    ax.set_rmax(40.0)
    ax.set_yticklabels(['','','','','50'])
    ax.set_rlabel_position(22.5)
    ax.set_xticks(np.arange(0,2*np.pi,np.pi/2.0))
    ax.set_xticklabels(['06','12', '18', '00'])
    ax.grid(True)
    ax.set_title(str(time_stamp))

    fig.colorbar(hs,ax=ax,shrink=0.7)

    return

# %%
ifile0 = '/backup/Data/ssusi/data/ssusi.jhuapl.edu/dataN/f18/apl/edr-aur/2017/001/'
ifile0 = ifile0 + 'PS.APL_V0105S027CB0006_SC.U_DI.A_GP.F18-SSUSI_PA.APL-EDR-AURORA_DD.20170101_SN.37156-00_DF.NC'

ssusi=Dataset(ifile0)
MLat = np.array(ssusi['LATITUDE_GEOMAGNETIC_GRID_MAP'])
MLT = np.array(ssusi['MLT_GRID_MAP'])
nodatavalue = ssusi.NO_DATA_IN_BIN_VALUE  # value in a no data bin
ut = ssusi['UT_N'][:]
vartmp = np.array(ssusi['DISK_RADIANCEDATA_INTENSITY_NORTH'])
image = vartmp[4,:,:]
energyfluxn = np.array(ssusi['ENERGY_FLUX_NORTH_MAP'])
fp = (ut == nodatavalue)
energyfluxn[fp] = np.nan
image[fp] = np.nan

starttime = ssusi.STARTING_TIME
stoptime = ssusi.STOPPING_TIME
yyyy = int(stoptime[:4])
ddd = int(stoptime[4:7])
date = pd.Timestamp(yyyy, 1, 1)+pd.Timedelta(ddd-1, 'D')

if starttime[:7] != stoptime[:7]:
    ut[ut > 20] = ut[ut > 20]-24

dataplot = energyfluxn
mlat = MLat
mlt = MLT

maxi = 10
mini = 0

timestamp = date+pd.Timedelta(np.nanmean(ut[image==image]),'h')

plot_SSUSI(dataplot,mlat,mlt,maxi,mini,timestamp)

plt.show()
# Out:
# /tmp/ipykernel_3888558/984369769.py:5: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   MLat = np.array(ssusi['LATITUDE_GEOMAGNETIC_GRID_MAP'])
# /tmp/ipykernel_3888558/984369769.py:6: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   MLT = np.array(ssusi['MLT_GRID_MAP'])
# /tmp/ipykernel_3888558/984369769.py:9: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   vartmp = np.array(ssusi['DISK_RADIANCEDATA_INTENSITY_NORTH'])
# /tmp/ipykernel_3888558/984369769.py:11: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   energyfluxn = np.array(ssusi['ENERGY_FLUX_NORTH_MAP'])

# %%
# inputs
# =======
sat_name = 'f18'
lat_threshold = 60 # if we want to make high-latitude plots

date_str = '20170101'  # date in yyyymmdd format
year = date_str[0:4]   # year
dayofyear = '001'      # day of year

# %%
# Date formatting
date_req = pd.to_datetime(date_str)      # convert to datetime object
print(date_req)
date_str_req = str(date_req.year) + str(date_req.month).rjust(2,'0') + str(date_req.day).rjust(2,'0')
# Out:
# 2017-01-01 00:00:00
# 20170101
# 20170101

# %%
# main
# =====
SSUSI_PATH = f'/backup/Data/ssusi/data/ssusi.jhuapl.edu/dataN/{sat_name}/apl/edr-aur/{year}/001/PS.APL_V0105S027CB0006_SC.U_DI.A_GP.F18-SSUSI_PA.APL-EDR-AURORA_DD.{date_str}_SN.37156-00_DF.NC'
ssusi=Dataset(SSUSI_PATH)

nodatavalue = ssusi.NO_DATA_IN_BIN_VALUE  # value in a no data bin
ut = ssusi['UT_N'][:]
vartmp = np.array(ssusi['DISK_RADIANCEDATA_INTENSITY_NORTH'])

# energy flux fig
image = vartmp[4,:,:]
energyflux_n = np.array(ssusi['ENERGY_FLUX_NORTH_MAP'])
fp = (ut == nodatavalue)
energyflux_n[fp] = np.nan
image[fp] = np.nan

starttime = ssusi.STARTING_TIME
print(f'starttime = {starttime}')
stoptime = ssusi.STOPPING_TIME
print(f'stoptime = {stoptime}')
yyyy = int(stoptime[:4])
ddd = int(stoptime[4:7])
date = pd.Timestamp(yyyy, 1, 1)+pd.Timedelta(ddd-1, 'D')

if starttime[:7] != stoptime[:7]:
    ut[ut > 20] = ut[ut > 20]-24

dataplot = energyflux_n
mlat = np.array(ssusi['LATITUDE_GEOMAGNETIC_GRID_MAP']) 
mlt = np.array(ssusi['MLT_GRID_MAP'])

maxi = 10
mini = 0

timestamp = date+pd.Timedelta(np.nanmean(ut[image==image]),'h')
plot_SSUSI(dataplot,mlat,mlt,maxi,mini,timestamp)

plt.show()
# Out:
# /tmp/ipykernel_3888558/2827736217.py:8: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   vartmp = np.array(ssusi['DISK_RADIANCEDATA_INTENSITY_NORTH'])
# /tmp/ipykernel_3888558/2827736217.py:12: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   energyflux_n = np.array(ssusi['ENERGY_FLUX_NORTH_MAP'])
# /tmp/ipykernel_3888558/2827736217.py:30: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mlat = np.array(ssusi['LATITUDE_GEOMAGNETIC_GRID_MAP'])
# /tmp/ipykernel_3888558/2827736217.py:31: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   mlt = np.array(ssusi['MLT_GRID_MAP'])
# starttime = 2017001014018
# stoptime = 2017001032209
# 2017-01-01 00:00:00
